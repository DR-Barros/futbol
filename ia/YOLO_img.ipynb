# %%
from ultralytics import YOLO
import cv2
import torch
import numpy as np
from collections import Counter


model = YOLO("yolov8n.pt")
model_line = YOLO("yolov8n_line_detail.pt")
model_inclinacion = YOLO("yolo11n_inclinacion.pt")
model.to('cuda' if torch.cuda.is_available() else 'cpu')
model_line.to('cuda' if torch.cuda.is_available() else 'cpu')
model_inclinacion.to('cuda' if torch.cuda.is_available() else 'cpu')
print("Model loaded")
# Out:
# Model loaded

# %%
foto = 21
field_map = {
    # LÍNEAS DE BORDE
    "Side line left":     (0, 0, 0, 68),
    "Side line right":    (105, 0, 105, 68),
    "Side line top":      (0, 68, 105, 68),
    "Side line bottom":   (0, 0, 105, 0),
    "Middle line":        (52.5, 0, 52.5, 68),

    # CÍRCULOS
    "Circle central":     {"center": (52.5, 34), "radius": 9.15},

    # ÁREA GRANDE IZQUIERDA
    "Big rect. left main":   (16.5, 13.85, 16.5, 54.15),
    "Big rect. left top":    (0, 54.15, 16.5, 54.15),
    "Big rect. left bottom": (0, 13.85, 16.5, 13.85),

    # ÁREA GRANDE DERECHA
    "Big rect. right main":   (88.5, 13.85, 88.5, 54.15),
    "Big rect. right top":    (105, 54.15, 88.5, 54.15),
    "Big rect. right bottom": (105, 13.85, 88.5, 13.85),

    # ÁREA CHICA IZQUIERDA
    "Small rect. left main":   (5.5, 24.84, 5.5, 43.16),
    "Small rect. left top":    (0, 43.16, 5.5, 43.16),
    "Small rect. left bottom": (0, 24.84, 5.5, 24.84),

    # ÁREA CHICA DERECHA
    "Small rect. right main":   (99.5, 24.84, 99.5, 43.16),
    "Small rect. right top":    (105, 43.16, 99.5, 43.16),
    "Small rect. right bottom": (105, 24.84, 99.5, 24.84),
}

intersecciones_reales = {
    "Side line left": {
        "Side line bottom": (0.0, 0.0),
        "Side line top": (0.0, 68.0),
    },
    "Side line right": {
        "Side line bottom": (105.0, 0.0),
        "Side line top": (105.0, 68.0),
    },
    "Side line top": {
        "Side line left": (0.0, 68.0),
        "Side line right": (105.0, 68.0),
    },
    "Side line bottom": {
        "Side line left": (0.0, 0.0),
        "Side line right": (105.0, 0.0),
    },
    "Middle line": {
        "Side line bottom": (52.5, 0.0),
        "Side line top": (52.5, 68.0),
    },
    "Big rect. left main": {
        "Big rect. left bottom": (16.5, 13.85),
        "Big rect. left top": (16.5, 54.15),
    },
    "Big rect. left top": {
        "Big rect. left main": (16.5, 54.15),
        "Side line left": (0.0, 54.15),
    },
    "Big rect. left bottom": {
        "Big rect. left main": (16.5, 13.85),
        "Side line left": (0.0, 13.85),
    },
    "Big rect. right main": {
        "Big rect. right bottom": (88.5, 13.85),
        "Big rect. right top": (88.5, 54.15),
    },
    "Big rect. right top": {
        "Big rect. right main": (88.5, 54.15),
        "Side line right": (105.0, 54.15),
    },
    "Big rect. right bottom": {
        "Big rect. right main": (88.5, 13.85),
        "Side line right": (105.0, 13.85),
    },
    "Small rect. left main": {
        "Small rect. left bottom": (5.5, 24.84),
        "Small rect. left top": (5.5, 43.16),
    },
    "Small rect. left top": {
        "Small rect. left main": (5.5, 43.16),
        "Side line left": (0.0, 43.16),
    },
    "Small rect. left bottom": {
        "Small rect. left main": (5.5, 24.84),
        "Side line left": (0.0, 24.84),
    },
    "Small rect. right main": {
        "Small rect. right bottom": (99.5, 24.84),
        "Small rect. right top": (99.5, 43.16),
    },
    "Small rect. right top": {
        "Small rect. right main": (99.5, 43.16),
        "Side line right": (105.0, 43.16),
    },
    "Small rect. right bottom": {
        "Small rect. right main": (99.5, 24.84),
        "Side line right": (105.0, 24.84),
    },
}
def segment_to_line(x1, y1, x2, y2, name):
    A = y2 - y1
    B = x1 - x2
    C = x2 * y1 - x1 * y2
    return A, B, -C, name

def intersection(line1, line2):
    A1, B1, C1, NAME1 = line1
    A2, B2, C2, NAME2 = line2
    D = A1 * B2 - A2 * B1
    if D == 0:
        return None  # Son paralelas
    x = (B2 * C1 - B1 * C2) / D
    y = (A1 * C2 - A2 * C1) / D
    return x, y, NAME1, NAME2

while True:
    #transformamos foto en un string de 5 digitos
    foto_path = str(foto).zfill(5)    
    img_path = f"SoccerNet/calibration/test/{foto_path}.jpg"
    print(f"Processing {img_path}")
    frame = cv2.imread(img_path)
    results = model.predict(frame, device='cuda' if torch.cuda.is_available() else 'cpu', verbose=False)
    lines = model_line.predict(frame, device='cuda' if torch.cuda.is_available() else 'cpu', verbose=False)
    inclinaciones = model_inclinacion.predict(frame, device='cuda' if torch.cuda.is_available() else 'cpu', verbose=False)

    annotated_frame = frame.copy()
    


    positions = []
    index = 0
    for result in results:
        boxes = result.boxes
        detections = []
        for box in boxes:
            cls_id = int(box.cls[0])  # Clase detectada
            if model.names[cls_id] == 'person':
                x1, y1, x2, y2 = box.xyxy[0].tolist()  
                x1, y1, x2, y2 = map(int, (x1, y1, x2, y2))
                #print(f"Person detected: {x1}, {y1}, {x2}, {y2}, {model.names[cls_id]}, {index}")
                positions.append({"pos":((x1+x2)/2, max(y1, y2)),"type": model.names[cls_id], "index": index})
                person_section = annotated_frame[y1:y2, x1:x2]
                small_section = cv2.resize(person_section, (20, 20), interpolation=cv2.INTER_LINEAR)
                hsv_section = cv2.cvtColor(small_section, cv2.COLOR_BGR2HSV)
                mask = cv2.inRange(hsv_section, np.array([35, 40, 40]), np.array([85, 255, 255]))
                non_green_pixels = hsv_section[mask == 0]
                quantized_pixels = (non_green_pixels // 32) * 32
                pixels = quantized_pixels.reshape(-1, 3)
                pixels_list = [tuple(pixel) for pixel in pixels]
                if len(pixels_list) > 0:
                    most_common = Counter(pixels_list).most_common(1)[0][0]
                    domimant_color_rgb = cv2.cvtColor(np.uint8([[most_common]]), cv2.COLOR_HSV2BGR)[0][0]
                    cv2.rectangle(annotated_frame, (x1, y1), (x2, y2), tuple(int(c) for c in domimant_color_rgb), 2)
                else:
                    cv2.rectangle(annotated_frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(annotated_frame, str(index), (int((x1+x2)/2), int(max(y1, y2))-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
                #ponemos un punto en la posicion de la persona
                cv2.circle(annotated_frame, (int((x1+x2)/2), int(max(y1, y2))), 5, (0, 255, 0), -1)
                index += 1
            #balon
            if model.names[cls_id] == 'sports ball':
                x1, y1, x2, y2 = box.xyxy[0].tolist()
                x1, y1, x2, y2 = map(int, (x1, y1, x2, y2))
                positions.append({"pos":((x1+x2)/2, min(y1, y2)),"type": model.names[cls_id], "index": index})
                cv2.rectangle(annotated_frame, (x1, y1), (x2, y2), (0, 0, 255), 2)
                cv2.putText(annotated_frame, str(index), (x1, y1 + 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)
                index += 1
                
    inclinaciones_boxes = []
    for inclinacion in inclinaciones:
        boxes = inclinacion.boxes
        for box in boxes:
            cls_id = int(box.cls[0])
            if model_inclinacion.names[cls_id] == "unknown":
                continue
            x1, y1, x2, y2 = box.xyxy[0].tolist()
            x1, y1, x2, y2 = map(int, (x1, y1, x2, y2))
            inclinaciones_boxes.append({"pos":(x1, y1, x2, y2),"type": model_inclinacion.names[cls_id]})         
                
    # Dibuja las líneas detectadas usando inclinaciones_boxes para determinar el sentido
    field_lines = []
    for line in lines:
        boxes = line.boxes
        for box in boxes:
            cls_id = int(box.cls[0])
            line_name = model_line.names[cls_id]
            if line_name in ['Circle right', 'Circle central', 'Circle left']:
                pass
            elif line_name in ["Goal right crossbar","Goal right post left","Goal right post right","Goal left post left","Goal left post left ","Goal left post left","Goal left post right","Goal left crossbar", 'unknown']:
                pass
            else:
                x1, y1, x2, y2 = box.xyxy[0].tolist()
                x1, y1, x2, y2 = map(int, (x1, y1, x2, y2))
                # Buscar la inclinación_box con mayor área de intersección
                max_iou = 0
                best_inclinacion = None
                for inc_box in inclinaciones_boxes:
                    ix1, iy1, ix2, iy2 = inc_box["pos"]
                    # calcular intersección
                    inter_x1 = max(x1, ix1)
                    inter_y1 = max(y1, iy1)
                    inter_x2 = min(x2, ix2)
                    inter_y2 = min(y2, iy2)
                    inter_w = max(0, inter_x2 - inter_x1)
                    inter_h = max(0, inter_y2 - inter_y1)
                    inter_area = inter_w * inter_h
                    area_line = (x2 - x1) * (y2 - y1)
                    area_inc = (ix2 - ix1) * (iy2 - iy1)
                    union_area = area_line + area_inc - inter_area
                    iou = inter_area / union_area if union_area > 0 else 0
                    if iou > max_iou:
                        max_iou = iou
                        best_inclinacion = inc_box
                # Si hay inclinación asociada, usar su sentido
                if best_inclinacion is not None:
                    sentido = best_inclinacion["type"]
                    if sentido == "r":
                        cv2.line(annotated_frame, (x1, y2), (x2, y1), (0, 255, 0), 2)
                        field_lines.append({"pos":(x1, y2, x2, y1),"type": line_name})
                    else:
                        cv2.line(annotated_frame, (x1, y1), (x2, y2), (255, 0, 0), 2)
                        field_lines.append({"pos":(x1, y1, x2, y2),"type": line_name})
                else:
                    #ponemos un rectangulo en la posicion de la linea
                    cv2.rectangle(annotated_frame, (x1, y1), (x2, y2), (0, 255, 255), 2)
                cv2.putText(annotated_frame, line_name, (x1, y1 + 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 255), 2)


    intersections = []
    names = []           
    for i, line1 in enumerate(field_lines):
        for j, line2 in enumerate(field_lines):
            if i >= j:
                continue
            if line1 != line2:
                pos1 = line1["pos"]
                pos2 = line2["pos"]
                # Convertir las coordenadas de la línea a la forma Ax + By + C = 0
                A1, B1, C1, NAME1 = segment_to_line(pos1[0], pos1[1], pos1[2], pos1[3], line1["type"])
                A2, B2, C2, NAME2 = segment_to_line(pos2[0], pos2[1], pos2[2], pos2[3], line2["type"])
                # Calcular la intersección
                intersection_point = intersection((A1, B1, C1, NAME1), (A2, B2, C2, NAME2))
                if intersection_point is not None:
                    x, y, name1, name2 = intersection_point
                    margin = 150
                    if x > 0 and y >0 and x < frame.shape[1] and y < frame.shape[0]:
                        intersections.append({"pos":(x, y),"lines": (name1, name2)})
                        names.append((name1, name2))
                        cv2.circle(annotated_frame, (int(intersection_point[0]), int(intersection_point[1])), 5, (255, 255, 0), -1)
                    elif x> 0 - margin and y >0 - margin and x < frame.shape[1] + margin and y < frame.shape[0] + margin:
                        intersections.append({"pos":(x, y),"lines": (name1, name2)})
                        names.append((name1, name2))
                    else:
                        print(f"Intersección fuera de los límites de la imagen: {intersection_point}")
    
    
    
                
            
    #si faltan intersecciones evaluar si hay lineas que estan completas y calcular la intersección que debería haber
    if len(intersections) < 4:
        margin = 5
        for line in field_lines:
            x1, y1, x2, y2 = line["pos"]
            #evalua que la linea este completa (ningun extremo cercano a los bordes de la imagen)
            if (x1 > margin and x2 < frame.shape[1] - margin) and (y1 > margin and y2 < frame.shape[0] - margin):
                # ver tipo de linea
                type = line["type"]
                #obtener intersecciones reales
                if type in intersecciones_reales:
                    interseccion_type = intersecciones_reales[type]
                    keys = list(interseccion_type.keys())
                    # si la linea es horizontal, asignamos el punto más alto como el punto de intersección más alto
                    if interseccion_type[keys[0]][1] == interseccion_type[keys[1]][1]:
                        # la intersección es horizontal
                        #evaluamos que punto de la imagen esta mas a la izquierda
                        if x1 < x2:
                            if interseccion_type[keys[0]][0] < interseccion_type[keys[1]][0]:
                                # la intersección es la primera
                                intersections.append({"pos":(x1, y1),"lines": (type, keys[0])})
                                intersections.append({"pos":(x2, y2),"lines": (type, keys[1])})
                            else:
                                # la intersección es la segunda
                                intersections.append({"pos":(x1, y1),"lines": (type, keys[1])})
                                intersections.append({"pos":(x2, y2),"lines": (type, keys[0])})
                        else:
                            if interseccion_type[keys[0]][0] < interseccion_type[keys[1]][0]:
                                # la intersección es la primera
                                intersections.append({"pos":(x1, y1),"lines": (type, keys[1])})
                                intersections.append({"pos":(x2, y2),"lines": (type, keys[0])})
                            else:
                                # la intersección es la segunda
                                intersections.append({"pos":(x1, y1),"lines": (type, keys[0])})
                                intersections.append({"pos":(x2, y2),"lines": (type, keys[1])})
                    else:
                        # la intersección es vertical
                        #evaluamos que punto de la imagen es más alto
                        if y1 < y2:
                            if interseccion_type[keys[0]][1] > interseccion_type[keys[1]][1]:
                                # la intersección es la primera
                                intersections.append({"pos":(x1, y1),"lines": (type, keys[0])})
                                intersections.append({"pos":(x2, y2),"lines": (type, keys[1])})
                            else:
                                # la intersección es la segunda
                                intersections.append({"pos":(x1, y1),"lines": (type, keys[1])})
                                intersections.append({"pos":(x2, y2),"lines": (type, keys[0])})
                        else:
                            if interseccion_type[keys[0]][1] > interseccion_type[keys[1]][1]:
                                # la intersección es la primera
                                intersections.append({"pos":(x1, y1),"lines": (type, keys[1])})
                                intersections.append({"pos":(x2, y2),"lines": (type, keys[0])})
                            else:
                                # la intersección es la segunda
                                intersections.append({"pos":(x1, y1),"lines": (type, keys[0])})
                                intersections.append({"pos":(x2, y2),"lines": (type, keys[1])})
                    names.append((type, keys[0]))
                    names.append((type, keys[1]))               
                    
                    
    #Lineas de campo
    field_lines_map = []
    for name, coords in field_map.items():
        if isinstance(coords, tuple):  # es una línea
            x1, y1, x2, y2 = coords
            field_lines_map.append(segment_to_line(x1, y1, x2, y2, name))
            
    # Intersección de líneas del campo        
    intersections_field = []
    for i, line1 in enumerate(field_lines_map):
        for j, line2 in enumerate(field_lines_map):
            if i >= j:
                continue
            point = intersection(line1, line2)
            if point is not None:
                x, y, name1, name2 = point
                if (name1, name2) in names or (name2, name1) in names:
                    intersections_field.append({
                        "pos": (x, y),
                        "lines": (name1, name2)
                    })
                             
    
    # Emparejar intersecciones de líneas detectadas con las intersecciones del campo
    matched_pairs = []
    for i in intersections:
        for f in intersections_field:
            if set(i["lines"]) == set(f["lines"]):
                matched_pairs.append((i["pos"], f["pos"]))  # (imagen, cancha)
                break 

    # Homografía 2d
    positions_homography = []
    intersection_homography = []        
    if len(matched_pairs) >= 4:
        
        src_pts = np.array([pt[0] for pt in matched_pairs], dtype=np.float32)
        dst_pts = np.array([pt[1] for pt in matched_pairs], dtype=np.float32)
        
        # Calcular la homografía
        H, _ = cv2.findHomography(src_pts, dst_pts, cv2.RANSAC)
        # Aplicar la homografía a los puntos de la imagen
        if H is None:
            print("No se pudo calcular la homografía", matched_pairs)
        else:
            for pos in positions:
                point = np.array([pos["pos"][0], pos["pos"][1], 1], dtype=np.float32)
                transformed_point = np.dot(H, point)
                transformed_point /= transformed_point[2]  # Normalizarq
                positions_homography.append({"pos":(transformed_point[0], transformed_point[1]),"type": pos["type"], "index": pos["index"]})
            # Aplicar la homografía a los puntos de intersección
            for pos in intersections:
                point = np.array([pos["pos"][0], pos["pos"][1], 1], dtype=np.float32)
                transformed_point = np.dot(H, point)
                transformed_point /= transformed_point[2]  # Normalizar
                intersection_homography.append({"pos":(transformed_point[0], transformed_point[1]),"lines": pos["lines"]})
            
            # Draw minimap of the field
            # Crear una imagen en blanco para el minimapa del campo
            field_map_img = np.ones((800, 1200, 3), dtype=np.uint8) * 255

            # Escalado para ajustar el campo a la imagen
            scale_x = 10  # 1 metro = 10 pixeles
            scale_y = 10
            offset_x = 50  # margen izquierdo
            offset_y = 50  # margen superior

            def to_img_coords(x, y):
                # Convierte coordenadas de metros a pixeles en la imagen
                return int(x * scale_x + offset_x), int(field_map_img.shape[0] - (y * scale_y + offset_y))

            # Dibujar líneas y círculos del campo
            for name, coords in field_map.items():
                if isinstance(coords, tuple):  # Línea
                    x1, y1, x2, y2 = coords
                    pt1 = to_img_coords(x1, y1)
                    pt2 = to_img_coords(x2, y2)
                    cv2.line(field_map_img, pt1, pt2, (255, 0, 0), 2)
                    if name == "Middle line":
                        center_x = x1
                        center_y = (y1 + y2) / 2
                        center_pt = to_img_coords(center_x, center_y)
                        cv2.circle(field_map_img, center_pt, 5, (255, 0, 0), -1)
                elif isinstance(coords, dict):  # Círculo
                    center = to_img_coords(coords["center"][0], coords["center"][1])
                    radius = int(coords["radius"] * scale_x)
                    cv2.circle(field_map_img, center, radius, (0, 255, 0), 2)

            # Dibujar posiciones proyectadas por homografía
            for pos in positions_homography:
                x, y = pos["pos"][0], pos["pos"][1]
                if np.isnan(x) or np.isnan(y) or np.isinf(x) or np.isinf(y):
                    continue
                px, py = to_img_coords(x, y)
                if pos["type"] == "person":
                    color = (0, 0, 255)  # rojo en BGR
                elif pos["type"] == "sports ball":
                    color = (255, 0, 0)  # azul en BGR
                else:
                    color = (0, 255, 0)  # verde en BGR
                cv2.circle(field_map_img, (px, py), 7, color, -1)
                cv2.putText(field_map_img, str(pos["index"]), (px-10, py-10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)

            cv2.putText(field_map_img, "Minimapa del campo y posiciones proyectadas", (30, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,0), 2)
            # Mostrar el campo
            cv2.imshow("Campo", field_map_img)                      
                    
    cv2.imshow("Detecciones", annotated_frame)
    # Esperar hasta que se presione una tecla, si es la tecla 'q', salir del bucle, si es 'w' avanzar a la siguiente imagen, si es 's' retroceder a la anterior
    key = cv2.waitKey(0)
    if key == ord('q'):
        break
    elif key == ord('w'):
        foto += 1
    elif key == ord('s'):
        foto -= 1
        if foto < 0:
            foto = 0
    else:
        continue
cv2.destroyAllWindows()
# Out:
# Processing SoccerNet/calibration/test/00021.jpg
# Intersección fuera de los límites de la imagen: (-3971.8704180378613, -51.32214655762276, 'Side line bottom', 'Side line top')
# Processing SoccerNet/calibration/test/00022.jpg
# Intersección fuera de los límites de la imagen: (2669.30324567638, -272.1888967859117, 'Big rect. left main', 'Small rect. left main')
# Intersección fuera de los límites de la imagen: (2618.82291888213, -256.8442724063125, 'Big rect. left main', 'Side line left')
# Intersección fuera de los límites de la imagen: (1175.4027785285691, 181.9155630034056, 'Big rect. left main', 'Big rect. left top')
# Intersección fuera de los límites de la imagen: (2469.097678369196, -224.02349943374858, 'Small rect. left main', 'Side line left')
# Intersección fuera de los límites de la imagen: (-1939.940080379978, -240.99598100109608, 'Big rect. left bottom', 'Small rect. left bottom')
# Intersección fuera de los límites de la imagen: (-1631.0657223205917, -152.63035100510365, 'Big rect. left bottom', 'Big rect. left top')
# Intersección fuera de los límites de la imagen: (-1767.8143578238924, -191.75266404935502, 'Big rect. left bottom', 'Small rect. left top')
# Intersección fuera de los límites de la imagen: (-1429.4717208182913, -128.59927797833936, 'Small rect. left bottom', 'Big rect. left top')
# Intersección fuera de los límites de la imagen: (-1600.5038659793815, -166.2577319587629, 'Small rect. left bottom', 'Small rect. left top')
# Intersección fuera de los límites de la imagen: (-1079.925855513308, -86.93155893536121, 'Big rect. left top', 'Small rect. left top')
# Processing SoccerNet/calibration/test/00023.jpg
# Processing SoccerNet/calibration/test/00024.jpg
# Intersección fuera de los límites de la imagen: (3260.7217537942665, -316.58178752107926, 'Big rect. right bottom', 'Small rect. right bottom')
# Intersección fuera de los límites de la imagen: (3085.1774193548385, -264.36290322580646, 'Big rect. right bottom', 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (2915.3420224719102, -213.84224719101124, 'Big rect. right bottom', 'Big rect. right top')
# Intersección fuera de los límites de la imagen: (-1294.0209580838323, -144.95209580838323, 'Small rect. right main', 'Side line right')
# Intersección fuera de los límites de la imagen: (-1599.9628036731374, -215.98872486341975, 'Small rect. right main', 'Big rect. right main')
# Intersección fuera de los límites de la imagen: (-1514.2739853009336, -190.0143017943455, 'Side line right', 'Big rect. right main')
# Intersección fuera de los límites de la imagen: (-212.88970221261022, 204.46780901680253, 'Big rect. right main', 'Big rect. right top')
# Intersección fuera de los límites de la imagen: (2913.304347826087, -235.7173913043478, 'Small rect. right bottom', 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (2689.676113360324, -183.665991902834, 'Small rect. right bottom', 'Big rect. right top')
# Intersección fuera de los límites de la imagen: (2241.0588235294117, -123.67647058823529, 'Small rect. right top', 'Big rect. right top')
# Processing SoccerNet/calibration/test/00025.jpg
# Intersección fuera de los límites de la imagen: (102.04916958041959, -291.2237762237762, 'Side line right', 'Small rect. right main')
# Intersección fuera de los límites de la imagen: (23123.833897700944, -232.23150953484227, 'Big rect. right bottom', 'Big rect. right top')
# Intersección fuera de los límites de la imagen: (200007.4972972973, -5540.864864864865, 'Big rect. right bottom', 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (4978.595484477893, 63.41392285983067, 'Big rect. right top', 'Small rect. right top')
# Processing SoccerNet/calibration/test/00026.jpg
# Intersección fuera de los límites de la imagen: (-54.07869198312236, -1512.7177215189874, 'Side line left', 'Small rect. right main')
# Intersección fuera de los límites de la imagen: (60.31861376381426, -1046.3958797719326, 'Side line left', 'Side line left')
# Intersección fuera de los límites de la imagen: (31.011947783759865, -1364.4953167637732, 'Small rect. right main', 'Side line left')
# Processing SoccerNet/calibration/test/00027.jpg
# Processing SoccerNet/calibration/test/00028.jpg
# Intersección fuera de los límites de la imagen: (-1222.365842894969, -165.1270962047661, 'Side line right', 'Small rect. right main')
# Intersección fuera de los límites de la imagen: (-1391.8, -202.9639263803681, 'Side line right', 'Big rect. right main')
# Intersección fuera de los límites de la imagen: (1292.345815267376, 396.4404151885429, 'Side line right', 'Big rect. right bottom')
# Intersección fuera de los límites de la imagen: (-1453.8104659613987, -223.27901154809012, 'Small rect. right main', 'Big rect. right main')
# Intersección fuera de los límites de la imagen: (1154.185543043952, 431.99636759898294, 'Small rect. right main', 'Big rect. right bottom')
# Intersección fuera de los límites de la imagen: (-235.01240144381038, 176.00820713435905, 'Big rect. right main', 'Side line top')
# Intersección fuera de los límites de la imagen: (3913.773117254528, -278.1916110581506, 'Big rect. right bottom', 'Small rect. right bottom')
# Intersección fuera de los límites de la imagen: (3840.9025744573446, -259.4381625441696, 'Big rect. right bottom', 'Big rect. right top')
# Intersección fuera de los límites de la imagen: (4163.47394540943, -342.4528535980149, 'Big rect. right bottom', 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (3612.583037729765, -200.67945823927766, 'Big rect. right bottom', 'Side line top')
# Intersección fuera de los límites de la imagen: (3781.596958174905, -251.95817490494298, 'Small rect. right bottom', 'Big rect. right top')
# Intersección fuera de los límites de la imagen: (4503.012158054711, -395.13981762917933, 'Small rect. right bottom', 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (3436.2505307855627, -183.41613588110403, 'Small rect. right bottom', 'Side line top')
# Intersección fuera de los límites de la imagen: (2706.144385026738, -116.31550802139037, 'Big rect. right top', 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (2551.0178571428573, -96.75, 'Big rect. right top', 'Side line top')
# Intersección fuera de los límites de la imagen: (2629.694736842105, -104.45263157894736, 'Small rect. right top', 'Side line top')
# Processing SoccerNet/calibration/test/00029.jpg
# Intersección fuera de los límites de la imagen: (161.97847322720693, -233.91986251808973, 'Side line right', 'Small rect. right main')
# Intersección fuera de los límites de la imagen: (163.7470424579654, -232.35592113221242, 'Side line right', 'Big rect. right main')
# Intersección fuera de los límites de la imagen: (163.71938033151693, -231.5929074776754, 'Small rect. right main', 'Big rect. right main')
# Intersección fuera de los límites de la imagen: (54001.80395528805, -535.054600171969, 'Big rect. right bottom', 'Big rect. right top')
# Intersección fuera de los límites de la imagen: (6303.4134362934365, 416.37606177606176, 'Big rect. right bottom', 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (18808.013856812933, 166.94919168591224, 'Big rect. right bottom', 'Small rect. right bottom')
# Intersección fuera de los límites de la imagen: (-729.4724782723202, 222.09744535159336, 'Big rect. right top', 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (-164165.04255319148, 2483.063829787234, 'Big rect. right top', 'Small rect. right bottom')
# Intersección fuera de los límites de la imagen: (4040.875, 353.875, 'Small rect. right top', 'Small rect. right bottom')
# Processing SoccerNet/calibration/test/00030.jpg
# Processing SoccerNet/calibration/test/00031.jpg
# Intersección fuera de los límites de la imagen: (-1554.548417572036, -258.7874350495985, 'Small rect. right main', 'Big rect. right main')
# Intersección fuera de los límites de la imagen: (-1191.1929824561403, -170.27777777777777, 'Small rect. right main', 'Side line right')
# Intersección fuera de los límites de la imagen: (-1449.4141652414933, -225.52780562599517, 'Big rect. right main', 'Side line right')
# Intersección fuera de los límites de la imagen: (-296.0166343953529, 139.35398697412427, 'Big rect. right main', 'Side line top')
# Intersección fuera de los límites de la imagen: (1202.5668898516476, 341.90057327906874, 'Big rect. right bottom', 'Side line right')
# Intersección fuera de los límites de la imagen: (4125.467153284671, -465.3766423357664, 'Big rect. right bottom', 'Small rect. right bottom')
# Intersección fuera de los límites de la imagen: (3294.1102362204724, -235.76377952755905, 'Big rect. right bottom', 'Big rect. right top')
# Intersección fuera de los límites de la imagen: (3766.865671641791, -366.33432835820895, 'Big rect. right bottom', 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (3473.932731747334, -285.4290401968827, 'Big rect. right bottom', 'Side line top')
# Intersección fuera de los límites de la imagen: (2855.838383838384, -180.97979797979798, 'Small rect. right bottom', 'Big rect. right top')
# Intersección fuera de los límites de la imagen: (3448.4792899408285, -313.73136094674555, 'Small rect. right bottom', 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (3168.482793522267, -251.01214574898785, 'Small rect. right bottom', 'Side line top')
# Intersección fuera de los límites de la imagen: (1989.6216216216217, -72.70270270270271, 'Big rect. right top', 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (5680.0, -534.0, 'Big rect. right top', 'Side line top')
# Intersección fuera de los límites de la imagen: (2855.226107226107, -215.71561771561773, 'Small rect. right top', 'Side line top')
# Processing SoccerNet/calibration/test/00032.jpg
# Intersección fuera de los límites de la imagen: (-28683.136616362193, -1486.7768069896742, 'Side line left', 'Small rect. left main')
# Intersección fuera de los límites de la imagen: (-22139.786181139123, -1046.4251478369126, 'Side line left', 'Small rect. right main')
# Intersección fuera de los límites de la imagen: (-273.55951169888095, 425.11902339776196, 'Side line left', 'Side line right')
# Intersección fuera de los límites de la imagen: (-12723.930831353919, -412.76085510688836, 'Side line left', 'Big rect. left main')
# Intersección fuera de los límites de la imagen: (-56571.15094339623, -3241.3207547169814, 'Small rect. left main', 'Side line right')
# Intersección fuera de los límites de la imagen: (-9011.06048312742, -249.12963304444034, 'Small rect. left main', 'Big rect. left main')
# Intersección fuera de los límites de la imagen: (-35865.6963562753, -1892.8562753036438, 'Small rect. right main', 'Side line right')
# Intersección fuera de los límites de la imagen: (-9710.635225126727, -279.9608388828148, 'Small rect. right main', 'Big rect. left main')
# Intersección fuera de los límites de la imagen: (-14008.032352633232, -469.35294733535756, 'Side line right', 'Big rect. left main')
# Processing SoccerNet/calibration/test/00033.jpg
# Processing SoccerNet/calibration/test/00034.jpg
# Intersección fuera de los límites de la imagen: (2890.1948849910723, -372.81146938346814, 'Big rect. left main', 'Small rect. left main')
# Intersección fuera de los límites de la imagen: (2725.401901469317, -319.94900605012964, 'Big rect. left main', 'Side line left')
# Intersección fuera de los límites de la imagen: (1161.6333209647496, 181.67829313543598, 'Big rect. left main', 'Big rect. left top')
# Intersección fuera de los límites de la imagen: (2326.4973958333335, -228.77083333333334, 'Small rect. left main', 'Side line left')
# Intersección fuera de los límites de la imagen: (-207.5464252553389, 350.439182915506, 'Side line left', 'Big rect. left bottom')
# Intersección fuera de los límites de la imagen: (-2141.4738760631835, -195.2332928311057, 'Big rect. left bottom', 'Small rect. left bottom')
# Intersección fuera de los límites de la imagen: (-2184.702152414194, -207.4304828388598, 'Big rect. left bottom', 'Big rect. left top')
# Intersección fuera de los límites de la imagen: (-2550.9410797478763, -310.76760756371607, 'Big rect. left bottom', 'Small rect. left top')
# Intersección fuera de los límites de la imagen: (-2222.7125748502995, -211.85029940119762, 'Small rect. left bottom', 'Big rect. left top')
# Intersección fuera de los límites de la imagen: (-3219.695652173913, -415.7786561264822, 'Small rect. left bottom', 'Small rect. left top')
# Intersección fuera de los límites de la imagen: (-1059.9575471698113, -76.64622641509433, 'Big rect. left top', 'Small rect. left top')
# Processing SoccerNet/calibration/test/00035.jpg
# Intersección fuera de los límites de la imagen: (676.2300490414623, -161.8800713330361, 'Side line left', 'Small rect. left main')
# Intersección fuera de los límites de la imagen: (727.3513101476893, -208.51462601238686, 'Side line left', 'Big rect. left main')
# Intersección fuera de los límites de la imagen: (726.3769968051118, -234.82108626198084, 'Small rect. left main', 'Big rect. left main')
# Intersección fuera de los límites de la imagen: (-38651.06544901065, -310.3389142567225, 'Big rect. left bottom', 'Big rect. left top')
# Intersección fuera de los límites de la imagen: (-4513.751852636036, 332.82786364598775, 'Big rect. left bottom', 'Small rect. left top')
# Intersección fuera de los límites de la imagen: (1563.2645480808915, 171.84729673957904, 'Big rect. left top', 'Small rect. left top')
# Processing SoccerNet/calibration/test/00036.jpg
# Intersección fuera de los límites de la imagen: (1967.8530553212004, 206.7766421598168, 'Small rect. left main', 'Side line right')
# Intersección fuera de los límites de la imagen: (1639.2243125904486, 242.0506512301013, 'Small rect. left main', 'Big rect. left main')
# Intersección fuera de los límites de la imagen: (1149.249657175123, 385.29329676534644, 'Side line right', 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (1854.9524083393242, 231.39741193386052, 'Side line right', 'Big rect. left main')
# Processing SoccerNet/calibration/test/00037.jpg
# Intersección fuera de los límites de la imagen: (2869.5592580949387, -141.30367808865137, 'Big rect. left main', 'Small rect. left main')
# Intersección fuera de los límites de la imagen: (2818.017648912701, -130.35991175543649, 'Big rect. left main', 'Side line left')
# Intersección fuera de los límites de la imagen: (1218.8, 209.2, 'Big rect. left main', 'Big rect. left top')
# Intersección fuera de los límites de la imagen: (2677.3706321162153, -110.07852375343542, 'Small rect. left main', 'Side line left')
# Intersección fuera de los límites de la imagen: (-265.1123451017068, 314.22936637830253, 'Side line left', 'Big rect. left bottom')
# Intersección fuera de los límites de la imagen: (-2884.492505353319, -244.57173447537474, 'Big rect. left bottom', 'Small rect. left bottom')
# Intersección fuera de los límites de la imagen: (-2382.2369062119365, -137.42387332521315, 'Big rect. left bottom', 'Big rect. left top')
# Intersección fuera de los límites de la imagen: (-3217.4210526315787, -315.5964912280702, 'Big rect. left bottom', 'Small rect. left top')
# Intersección fuera de los límites de la imagen: (-2063.534059945504, -106.7465940054496, 'Small rect. left bottom', 'Big rect. left top')
# Intersección fuera de los límites de la imagen: (-3676.476274165202, -377.53251318101934, 'Small rect. left bottom', 'Small rect. left top')
# Intersección fuera de los límites de la imagen: (-688.4357848518111, 25.61580680570801, 'Big rect. left top', 'Small rect. left top')
# Processing SoccerNet/calibration/test/00038.jpg
# Intersección fuera de los límites de la imagen: (4902.288461538462, 19.5, 'Big rect. right main', 'Big rect. left main')
# Intersección fuera de los límites de la imagen: (47100.05374592834, -1536.7296416938111, 'Big rect. right main', 'Side line right')
# Intersección fuera de los límites de la imagen: (41653.25, -1309.4638386648123, 'Big rect. left main', 'Side line right')
# Processing SoccerNet/calibration/test/00039.jpg
# Intersección fuera de los límites de la imagen: (-1237.6962397179789, -116.31139835487662, 'Side line right', 'Big rect. right main')
# Intersección fuera de los límites de la imagen: (-1922.5555555555557, -225.88888888888889, 'Side line right', 'Small rect. right main')
# Intersección fuera de los límites de la imagen: (-1076.2598897042858, -78.09084198184897, 'Big rect. right main', 'Small rect. right main')
# Intersección fuera de los límites de la imagen: (2377.226209048362, -4.669266770670827, 'Big rect. right top', 'Side line top')
# Intersección fuera de los límites de la imagen: (2671.1524163568774, -30.033457249070633, 'Big rect. right top', 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (2524.301935483871, -13.990967741935483, 'Side line top', 'Small rect. right top')
# Processing SoccerNet/calibration/test/00040.jpg
# Intersección fuera de los límites de la imagen: (1196.66029345031, 454.62873997882315, 'Side line right', 'Big rect. right bottom')
# Processing SoccerNet/calibration/test/00041.jpg
# Intersección fuera de los límites de la imagen: (-1856.7671701729566, -158.86761283256516, 'Big rect. right main', 'Side line right')
# Intersección fuera de los límites de la imagen: (-2099.415751177058, -210.2088743044657, 'Big rect. right main', 'Small rect. right main')
# Intersección fuera de los límites de la imagen: (-158.02912621359224, 200.5631067961165, 'Big rect. right main', 'Big rect. right top')
# Intersección fuera de los límites de la imagen: (-328.5429214446469, 164.48462115528883, 'Big rect. right main', 'Side line top')
# Intersección fuera de los límites de la imagen: (-1360.1439862995653, -84.93847977868529, 'Side line right', 'Small rect. right main')
# Intersección fuera de los límites de la imagen: (1275.7411423118313, 307.4489655032385, 'Side line right', 'Big rect. right bottom')
# Intersección fuera de los límites de la imagen: (1128.3624944643504, 336.7416160070856, 'Small rect. right main', 'Big rect. right bottom')
# Intersección fuera de los límites de la imagen: (3497.961367013373, -134.23455741880704, 'Big rect. right bottom', 'Big rect. right top')
# Intersección fuera de los límites de la imagen: (4283.200986436498, -290.30702836004934, 'Big rect. right bottom', 'Small rect. right bottom')
# Intersección fuera de los límites de la imagen: (3781.4036363636365, -190.57090909090908, 'Big rect. right bottom', 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (3907.862673484295, -215.7056245434624, 'Big rect. right bottom', 'Side line top')
# Intersección fuera de los límites de la imagen: (3058.644426362897, -94.00406834825061, 'Big rect. right top', 'Small rect. right bottom')
# Intersección fuera de los límites de la imagen: (2470.7305699481867, -40.16580310880829, 'Big rect. right top', 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (27896.0, -2368.4871794871797, 'Big rect. right top', 'Side line top')
# Intersección fuera de los límites de la imagen: (3357.8076923076924, -141.96153846153845, 'Small rect. right bottom', 'Small rect. right top')
# Intersección fuera de los límites de la imagen:
 'Big rect. left bottom')
# Intersección fuera de los límites de la imagen: (-1691.3245033112582, -71.74172185430463, 'Small rect. left top', 'Side line top')
# Intersección fuera de los límites de la imagen: (-3262.6347992351816, -196.7323135755258, 'Big rect. left bottom', 'Side line top')
# Processing SoccerNet/calibration/test/00045.jpg
# Processing SoccerNet/calibration/test/00044.jpg
# Intersección fuera de los límites de la imagen: (3076.7433746425168, -207.79866539561488, 'Small rect. left main', 'Big rect. left main')
# Intersección fuera de los límites de la imagen: (3341.4435483870966, -252.83064516129033, 'Small rect. left main', 'Side line left')
# Intersección fuera de los límites de la imagen: (-347.81070873139305, 374.80182181737393, 'Small rect. left main', 'Big rect. left bottom')
# Intersección fuera de los límites de la imagen: (3137.1067360885127, -220.9616010413277, 'Big rect. left main', 'Side line left')
# Intersección fuera de los límites de la imagen: (1142.4850703184536, 213.98893841073368, 'Big rect. left main', 'Big rect. left top')
# Intersección fuera de los límites de la imagen: (1345.1481917577796, 169.79587888982337, 'Big rect. left main', 'Side line top')
# Intersección fuera de los límites de la imagen: (-496.2141032192131, 345.7031170158406, 'Side line left', 'Big rect. left bottom')
# Intersección fuera de los límites de la imagen: (-2445.9332638164756, -111.17518248175182, 'Big rect. left top', 'Small rect. left bottom')
# Intersección fuera de los límites de la imagen: (-928.7332521315469, 26.30572472594397, 'Big rect. left top', 'Small rect. left top')
# Intersección fuera de los límites de la imagen: (-3153.101083032491, -175.25511432009628, 'Big rect. left top', 'Big rect. left bottom')
# Intersección fuera de los límites de la imagen: (-4306.212624584718, -279.74418604651163, 'Big rect. left top', 'Side line top')
# Intersección fuera de los límites de la imagen: (-4128.834951456311, -385.13592233009706, 'Small rect. left bottom', 'Small rect. left top')
# Intersección fuera de los límites de la imagen: (-4686.41095890411, -475.90410958904107, 'Small rect. left bottom', 'Big rect. left bottom')
# Intersección fuera de los límites de la imagen: (-2693.3015873015875, -151.44444444444446, 'Small rect. left bottom', 'Side line top')
# Intersección fuera de los límites de la imagen: (-4403.775933609959, -420.48547717842325, 'Small rect. left top', 'Big rect. left bottom')
# Intersección fuera de los límites de la imagen: (-1691.3245033112582, -71.74172185430463, 'Small rect. left top', 'Side line top')
# Intersección fuera de los límites de la imagen: (-3262.6347992351816, -196.7323135755258, 'Big rect. left bottom', 'Side line top')
# Processing SoccerNet/calibration/test/00045.jpg
# Processing SoccerNet/calibration/test/00046.jpg
# Processing SoccerNet/calibration/test/00047.jpg
# Intersección fuera de los límites de la imagen: (3227.449609145163, -167.21610490039507, 'Big rect. left main', 'Small rect. left main')
# Intersección fuera de los límites de la imagen: (3174.057921207041, -156.46898575020955, 'Big rect. left main', 'Side line left')
# Intersección fuera de los límites de la imagen: (1123.2478075106815, 256.33498238512857, 'Big rect. left main', 'Small rect. left top')
# Intersección fuera de los límites de la imagen: (1311.1950681635926, 218.50340817963112, 'Big rect. left main', 'Big rect. left top')
# Intersección fuera de los límites de la imagen: (3026.212505663797, -135.61304938830992, 'Small rect. left main', 'Side line left')
# Intersección fuera de los límites de la imagen: (-2224.03661971831, -171.9042253521127, 'Big rect. left bottom', 'Small rect. left bottom')
# Intersección fuera de los límites de la imagen: (-2356.2537313432836, -202.20398009950247, 'Big rect. left bottom', 'Small rect. left top')
# Intersección fuera de los límites de la imagen: (-2533.8396946564885, -242.90076335877862, 'Big rect. left bottom', 'Big rect. left top')
# Intersección fuera de los límites de la imagen: (-2520.717079530639, -223.877444589309, 'Small rect. left bottom', 'Small rect. left top')
# Intersección fuera de los límites de la imagen: (-2836.915343915344, -279.26984126984127, 'Small rect. left bottom', 'Big rect. left top')
# Intersección fuera de los límites de la imagen: (-4001.5526315789475, -419.0263157894737, 'Small rect. left top', 'Big rect. left top')
# Processing SoccerNet/calibration/test/00046.jpg
# Processing SoccerNet/calibration/test/00047.jpg
# Intersección fuera de los límites de la imagen: (3227.449609145163, -167.21610490039507, 'Big rect. left main', 'Small rect. left main')
# Intersección fuera de los límites de la imagen: (3174.057921207041, -156.46898575020955, 'Big rect. left main', 'Side line left')
# Intersección fuera de los límites de la imagen: (1123.2478075106815, 256.33498238512857, 'Big rect. left main', 'Small rect. left top')
# Intersección fuera de los límites de la imagen: (1311.1950681635926, 218.50340817963112, 'Big rect. left main', 'Big rect. left top')
# Intersección fuera de los límites de la imagen: (3026.212505663797, -135.61304938830992, 'Small rect. left main', 'Side line left')
# Intersección fuera de los límites de la imagen: (-2224.03661971831, -171.9042253521127, 'Big rect. left bottom', 'Small rect. left bottom')
# Intersección fuera de los límites de la imagen: (-2356.2537313432836, -202.20398009950247, 'Big rect. left bottom', 'Small rect. left top')
# Intersección fuera de los límites de la imagen: (-2533.8396946564885, -242.90076335877862, 'Big rect. left bottom', 'Big rect. left top')
# Intersección fuera de los límites de la imagen: (-2520.717079530639, -223.877444589309, 'Small rect. left bottom', 'Small rect. left top')
# Intersección fuera de los límites de la imagen: (-2836.915343915344, -279.26984126984127, 'Small rect. left bottom', 'Big rect. left top')
# Intersección fuera de los límites de la imagen: (-4001.5526315789475, -419.0263157894737, 'Small rect. left top', 'Big rect. left top')
# Processing SoccerNet/calibration/test/00048.jpg
# Intersección fuera de los límites de la imagen: (78.35265700483092, -843.4541062801933, 'Small rect. right top', 'Big rect. left bottom')
# Intersección fuera de los límites de la imagen:
 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (5590.00370994941, -115.44080944350759, 'Side line top', 'Big rect. right bottom')
# Intersección fuera de los límites de la imagen: (3263.9881656804732, -4.970414201183432, 'Side line top', 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (8239.7109375, -431.4609375, 'Big rect. right bottom', 'Small rect. right top')
# Processing SoccerNet/calibration/test/00093.jpg
# Intersección fuera de los límites de la imagen: (2064.967213114754, -23.154098360655738, 'Middle line', 'Middle line')
# Intersección fuera de los límites de la imagen: (21337.54588796186, -458.3413587604291, 'Middle line', 'Small rect. right main')
# Intersección fuera de los límites de la imagen: (21058.494089834516, -452.0401891252955, 'Middle line', 'Small rect. left main')
# Intersección fuera de los límites de la imagen: (13016.278566746778, -270.4417740878305, 'Middle line', 'Big rect. right main')
# Intersección fuera de los límites de la imagen: (24482.530266343827, -591.4866828087168, 'Middle line', 'Small rect. right main')
# Intersección fuera de los límites de la imagen: (24102.154491017965, -581.8433532934132, 'Middle line', 'Small rect. left main')
# Intersección fuera de los límites de la imagen: (14724.922805469783, -344.11071901191, 'Middle line', 'Big rect. right main')
# Intersección fuera de los límites de la imagen: (3349.4137931034484, 303.2, 'Small rect. right main', 'Small rect. left main')
# Intersección fuera de los límites de la imagen: (-197825.859375, 8820.109375, 'Small rect. right main', 'Big rect. right main')
# Intersección fuera de los límites de la imagen: (-331530.1790393013, 14584.829694323143, 'Small rect. left main', 'Big rect. right main')
# Processing SoccerNet/calibration/test/00094.jpg
# Intersección fuera de los límites de la imagen: (-1511.0824372759857, -235.14934289127837, 'Side line right', 'Small rect. right main')
# Intersección fuera de los límites de la imagen: (-1627.8510248291952, -262.00755429650616, 'Side line right', 'Big rect. right main')
# Intersección fuera de los límites de la imagen: (1298.2843047187257, 411.03956332398735, 'Side line right', 'Big rect. right bottom')
# Intersección fuera de los límites de la imagen: (-1670.391785150079, -275.99789362822537, 'Small rect. right main', 'Big rect. right main')
# Intersección fuera de los límites de la imagen: (-295.64970540974826, 176.112224857806, 'Big rect. right main', 'Side line top')
# Intersección fuera de los límites de la imagen: (6786.722826086957, -325.92391304347825, 'Big rect. right bottom', 'Small rect. right bottom')
# Intersección fuera de los límites de la imagen: (5923.248806191339, -209.98040507162852, 'Big rect. right bottom', 'Big rect. right top')
# Intersección fuera de los límites de la imagen: (7221.677364864865, -384.3277027027027, 'Big rect. right bottom', 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (6481.174528301887, -284.89622641509436, 'Big rect. right bottom', 'Side line top')
# Intersección fuera de los límites de la imagen: (5451.391093117409, -175.88663967611336, 'Small rect. right bottom', 'Big rect. right top')
# Intersección fuera de los límites de la imagen: (7706.931818181818, -429.3181818181818, 'Small rect. right bottom', 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (6330.124137931034, -274.62068965517244, 'Small rect. right bottom', 'Side line top')
# Intersección fuera de los límites de la imagen: (3285.867165575304, -19.418147801683816, 'Big rect. right top', 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (14667.181395348836, -841.7674418604652, 'Big rect. right top', 'Side line top')
# Intersección fuera de los límites de la imagen: (5234.594890510949, -200.09489051094891, 'Small rect. right top', 'Side line top')
# Processing SoccerNet/calibration/test/00095.jpg
# Intersección fuera de los límites de la imagen: (19.744363978560614, -321.53713023198725, 'Side line right', 'Small rect. right main')
# Intersección fuera de los límites de la imagen: (8170.281343400975, 195.87163756488908, 'Big rect. right bottom', 'Side line top')
# Processing SoccerNet/calibration/test/00096.jpg
# Intersección fuera de los límites de la imagen: (-1558.1204489103484, -240.10348427508808, 'Big rect. right main', 'Small rect. right main')
# Intersección fuera de los límites de la imagen: (-1543.6242786437476, -235.40720432094963, 'Big rect. right main', 'Side line right')
# Intersección fuera de los límites de la imagen: (-298.09315379969445, 168.1037055458841, 'Big rect. right main', 'Side line top')
# Intersección fuera de los límites de la imagen: (-1502.1734913793102, -225.95959051724137, 'Small rect. right main', 'Side line right')
# Intersección fuera de los límites de la imagen: (1169.3964760173403, 382.95432806600473, 'Side line right', 'Big rect. right bottom')
# Intersección fuera de los límites de la imagen: (5237.9149689991145, -173.42426926483614, 'Big rect. right bottom', 'Big rect. right top')
# Intersección fuera de los límites de la imagen: (13412.738372093023, -1291.3488372093022, 'Big rect. right bottom', 'Small rect. right bottom')
# Intersección fuera de los límites de la imagen: (7353.906976744186, -462.7906976744186, 'Big rect. right bottom', 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (4936.962047661077, -132.2683142100618, 'Big rect. right bottom', 'Side line top')
# Intersección fuera de los límites de la imagen: (3834.457076566125, -71.18561484918793, 'Big rect. right top', 'Small rect. right bottom')
# Intersección fuera de los límites de la imagen: (2373.8048780487807, 35.21951219512195, 'Big rect. right top', 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (3693.817543859649, -60.940350877192984, 'Big rect. right top', 'Side line top')
# Intersección fuera de los límites de la imagen: (5282.511627906977, -255.65116279069767, 'Small rect. right bottom', 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (3803.3795674869502, -67.22669649515286, 'Small rect. right bottom', 'Side line top')
# Intersección fuera de los límites de la imagen: (2852.923076923077, -12.692307692307692, 'Small rect. right top', 'Side line top')
# Processing SoccerNet/calibration/test/00097.jpg
# Intersección fuera de los límites de la imagen: (1219.9443877509368, 393.06327811839236, 'Side line right', 'Side line bottom')
# Intersección fuera de los límites de la imagen: (3056.1730596680127, 108.27153432032301, 'Big rect. right bottom', 'Side line bottom')
# Intersección fuera de los límites de la imagen: (3771.0105042016808, 33.75180072028812, 'Big rect. right bottom', 'Side line top')
# Intersección fuera de los límites de la imagen: (4195.725217391305, -10.523478260869565, 'Big rect. right bottom', 'Big rect. right top')
# Intersección fuera de los límites de la imagen: (43666.4358974359, -4125.2307692307695, 'Big rect. right bottom', 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (1136.1876495931067, 406.0536141694591, 'Side line bottom', 'Small rect. right main')
# Intersección fuera de los límites de la imagen: (3407.0062831060523, 53.858700552237124, 'Side line bottom', 'Side line top')
# Intersección fuera de los límites de la imagen: (3537.685034204854, 33.59094742760753, 'Side line bottom', 'Big rect. right top')
# Intersección fuera de los límites de la imagen: (4997.052039381153, -192.75105485232066, 'Side line bottom', 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (2431.906221821461, 107.72137060414788, 'Side line top', 'Big rect. right top')
# Intersección fuera de los límites de la imagen: (1579.2835302293258, 154.81862404447534, 'Side line top', 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (1288.948087431694, 184.34426229508196, 'Big rect. right top', 'Small rect. right top')
# Processing SoccerNet/calibration/test/00098.jpg
# Intersección fuera de los límites de la imagen: (538.1851085832471, -328.4043433298863, 'Small rect. left top', 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (541.1053315994799, -322.4369310793238, 'Small rect. right top', 'Small rect. right bottom')
# Processing SoccerNet/calibration/test/00099.jpg
# Processing SoccerNet/calibration/test/00100.jpg
# Intersección fuera de los límites de la imagen: (73.19734539089848, -318.24081096849477, 'Side line right', 'Small rect. right main')
# Intersección fuera de los límites de la imagen: (52.84946073218897, -339.8924502506456, 'Side line right', 'Big rect. right main')
# Intersección fuera de los límites de la imagen: (53.64291632145816, -351.00082850041423, 'Small rect. right main', 'Big rect. right main')
# Intersección fuera de los límites de la imagen: (9309.61375892727, 212.1074916192975, 'Big rect. right bottom', 'Side line top')
# Intersección fuera de los límites de la imagen: (111494.65363128492, -2322.5083798882683, 'Big rect. right bottom', 'Small rect. right bottom')
# Intersección fuera de los límites de la imagen: (6452.216480826761, 166.64889855860756, 'Side line top', 'Small rect. right bottom')
# Processing SoccerNet/calibration/test/00101.jpg
# Intersección fuera de los límites de la imagen: (-887.6618957366621, -172.68808138901596, 'Big rect. right main', 'Side line right')
# Intersección fuera de los límites de la imagen: (-924.0991129965291, -185.23563440030853, 'Big rect. right main', 'Small rect. right main')
# Intersección fuera de los límites de la imagen: (-789.3733311624878, -150.0185607294041, 'Side line right', 'Small rect. right main')
# Intersección fuera de los límites de la imagen: (1331.654933481153, 339.1807095343681, 'Side line right', 'Big rect. right bottom')
# Intersección fuera de los límites de la imagen: (1159.2420839988724, 359.34595508785117, 'Small rect. right main', 'Big rect. right bottom')
# Intersección fuera de los límites de la imagen: (6159.322762299941, -225.4588026081802, 'Big rect. right bottom', 'Big rect. right top')
# Intersección fuera de los límites de la imagen: (5519.905547226387, -150.67316341829084, 'Big rect. right bottom', 'Side line top')
# Intersección fuera de los límites de la imagen: (9723.348066298342, -642.3038674033149, 'Big rect. right bottom', 'Small rect. right bottom')
# Intersección fuera de los límites de la imagen: (8413.56338028169, -489.11267605633805, 'Big rect. right bottom', 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (3457.95567867036, -45.82825484764543, 'Big rect. right top', 'Side line top')
# Intersección fuera de los límites de la imagen: (5009.652377240842, -149.01013250194856, 'Big rect. right top', 'Small rect. right bottom')
# Intersección fuera de los límites de la imagen: (2945.9736585365854, -11.783414634146341, 'Big rect. right top', 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (4558.344322344323, -101.78021978021978, 'Side line top', 'Small rect. right bottom')
# Intersección fuera de los límites de la imagen: (3165.752767527675, -30.970479704797047, 'Side line top', 'Small rect. right top')
# Intersección fuera de los límites de la imagen: (7484.393617021276, -407.99468085106383, 'Small rect. right bottom', 'Small rect. right top')
# Processing SoccerNet/calibration/test/00102.jpg
# Processing SoccerNet/calibration/test/00103.jpg
# Intersección fuera de los límites de la imagen: (2104.937188716588, -209.99747710911504, 'Big rect. left main', 'Side line left')
# Intersección fuera de los límites de la imagen: (2056.1579230723214, -194.14966800263204, 'Big rect. left main', 'Small rect. left main')
# Intersección fuera de los límites de la imagen: (2265.7879953828397, -246.23566756444785, 'Side line left', 'Small rect. left main')
# Intersección fuera de los límites de la imagen: (-253.9810907358895, 321.44486782567276, 'Side line left', 'Big rect. left bottom')
# Intersección fuera de los límites de la imagen: (-3622.7132558481685, -148.29866117404737, 'Big rect. left bottom', 'Big rect. left top')
# Intersección fuera de los límites de la imagen: (-6441.898648648648, -541.4121621621622, 'Big rect. left bottom', 'Small rect. left bottom')
# Intersección fuera de los límites de la imagen: (-3637.2215225041673, -150.32172624560104, 'Big rect. left bottom', 'Side line top')
# Intersección fuera de los límites de la imagen: (-6241.139275766017, -513.4178272980502, 'Big rect. left bottom', 'Small rect. left top')
# Intersección fuera de los límites de la imagen: (-2753.604235605559, -86.69093315684977, 'Big rect. left top', 'Small rect. left bottom')
# Intersección fuera de los límites de la imagen: (-3724.4199669966997, -155.5082508250825, 'Big rect. left top', 'Side line top')
# Intersección fuera de los límites de la imagen: (-954.0907997594709, 40.869512928442575, 'Big rect. left top', 'Small rect. left top')
# Intersección fuera de los límites de la imagen: (-2927.1500399042297, -108.08699122106944, 'Small rect. left bottom', 'Side line top')
# Intersección fuera de los límites de la imagen: (-6065.347305389221, -494.98802395209583, 'Small rect. left bottom', 'Small rect. left top')
# Intersección fuera de los límites de la imagen: (-1650.7488433575677, -32.167217448777265, 'Side line top', 'Small rect. left top')
# Processing SoccerNet/calibration/test/00102.jpg
# Processing SoccerNet/calibration/test/00103.jpg
# Intersección fuera de los límites de la imagen: (2104.937188716588, -209.99747710911504, 'Big rect. left main', 'Side line left')
# Intersección fuera de los límites de la imagen: (2056.1579230723214, -194.14966800263204, 'Big rect. left main', 'Small rect. left main')
# Intersección fuera de los límites de la imagen: (2265.7879953828397, -246.23566756444785, 'Side line left', 'Small rect. left main')
# Intersección fuera de los límites de la imagen: (-253.9810907358895, 321.44486782567276, 'Side line left', 'Big rect. left bottom')
# Intersección fuera de los límites de la imagen: (-3622.7132558481685, -148.29866117404737, 'Big rect. left bottom', 'Big rect. left top')
# Intersección fuera de los límites de la imagen: (-6441.898648648648, -541.4121621621622, 'Big rect. left bottom', 'Small rect. left bottom')
# Intersección fuera de los límites de la imagen: (-3637.2215225041673, -150.32172624560104, 'Big rect. left bottom', 'Side line top')
# Intersección fuera de los límites de la imagen: (-6241.139275766017, -513.4178272980502, 'Big rect. left bottom', 'Small rect. left top')
# Intersección fuera de los límites de la imagen: (-2753.604235605559, -86.69093315684977, 'Big rect. left top', 'Small rect. left bottom')
# Intersección fuera de los límites de la imagen: (-3724.4199669966997, -155.5082508250825, 'Big rect. left top', 'Side line top')
# Intersección fuera de los límites de la imagen: (-954.0907997594709, 40.869512928442575, 'Big rect. left top', 'Small rect. left top')
# Intersección fuera de los límites de la imagen: (-2927.1500399042297, -108.08699122106944, 'Small rect. left bottom', 'Side line top')
# Intersección fuera de los límites de la imagen: (-6065.347305389221, -494.98802395209583, 'Small rect. left bottom', 'Small rect. left top')
# Intersección fuera de los límites de la imagen: (-1650.7488433575677, -32.167217448777265, 'Side line top', 'Small rect. left top')
# Processing SoccerNet/calibration/test/00104.jpg
# Intersección fuera de los límites de la imagen: (19648.666666666668, -296.326842837274, 'Side line right', 'Big rect. left main')
# Intersección fuera de los límites de la imagen: (34739.0, -925.9652294853964, 'Side line right', 'Big rect. right main')
